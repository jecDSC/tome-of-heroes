# %%
import pandas as pd
import bs4
import requests
import plotly.express as px
import kaleido
import regex

# %%
fe13 = requests.get('https://fireemblemwiki.org/wiki/List_of_characters_in_Fire_Emblem_Awakening#Playable_characters')
fe13 = bs4.BeautifulSoup(fe13.text)

# %%
fe13
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of characters in Fire Emblem Awakening - Fire Emblem Wiki</title>
# ...
