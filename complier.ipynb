# %%
import pandas as pd
import bs4
import requests
import plotly.express as px

# %%
# heroes = requests.get('https://feheroes.fandom.com/wiki/Level_40_stats_table')

# %%
# heroes = bs4.BeautifulSoup(heroes.text)

# %%
rows = heroes.find_all('tr', attrs={'class':'hero-filter-element'})
len(rows)
rows[0]
# Out:
# <tr class="hero-filter-element" data-abilities="" data-availability-classes="regular_4_3_2_1" data-move-type="Cavalry" data-titles="1" data-weapon-props="Lance;Blue;Close;Melee;Physical" data-weapon-type="Blue Lance"><td><span typeof="mw:File"><a href="/wiki/Abel:_The_Panther" title="Abel: The Panther"><img class="mw-file-element" data-image-key="Abel_The_Panther_Face_FC.webp" data-image-name="Abel The Panther Face FC.webp" data-relevant="0" decoding="async" height="30" loading="lazy" src="https://static.wikia.nocookie.net/feheroes_gamepedia_en/images/7/7c/Abel_The_Panther_Face_FC.webp/revision/latest/scale-to-width-down/30?cb=20190920195422" width="30"/></a></span></td><td><a href="/wiki/Abel:_The_Panther" title="Abel: The Panther">Abel: The Panther</a></td><td data-sort-value="1"><span class="mw-default-size inline-icon" typeof="mw:File"><span><img alt="Shadow Dragon / (New) Mystery" class="mw-file-element" data-image-key="Icon_MiniUnit_Head_1.png" data-image-name="Icon MiniUnit Head 1.png" data-relevant="0" decoding="async" height="26" loading="lazy" src="https://static.wikia.nocookie.net/feheroes_gamepedia_en/images/1/12/Icon_MiniUnit_Head_1.png/revision/latest/scale-to-width-down/27?cb=20200531064315" width="27"/></span></span></td><td data-sort-value="3"><span class="mw-default-size inline-icon" typeof="mw:File"><span><img alt="Cavalry" class="mw-file-element lazyload" data-image-key="Icon_Move_Cavalry.png" data-image-name="Icon Move Cavalry.png" data-relevant="0" data-src="https://static.wikia.nocookie.net/feheroes_gamepedia_en/images/9/9f/Icon_Move_Cavalry.png/revision/latest/scale-to-width-down/25?cb=20180513212041" decoding="async" height="26" loading="lazy" src="...%3D%3D" width="25"/></span></span></td><td data-sort-value="7"><span class="mw-default-size inline-icon" typeof="mw:File"><span><img alt="Blue Lance" class="mw-file-element lazyload" data-image-key="Icon_Class_Blue_Lance.png" data-image-name="Icon Class Blue Lance.png" data-relevant="0" data-src="https://static.wikia.nocookie.net/feheroes_gamepedia_en/images/6/60/Icon_Class_Blue_Lance.png/revision/latest/scale-to-width-down/26?cb=20220605130727" decoding="async" height="26" loading="lazy" src="...%3D%3D" width="26"/></span></span></td><td>39</td><td>33</td><td>32</td><td>25</td><td>25</td><td>154</td></tr>

# %%
# test[0].find('a').title()

# %%
heroes_table = pd.DataFrame(columns=['Hero', 'Entry', 'Move', 'Weapon', 'HP', 'Atk', 'Spd', 'Def', 'Res', 'Total'])
for i in range(len(rows)):
    row = rows[i].find_all('td')
    heroes_table.loc[len(heroes_table)] = [
        row[0].find('a').get('title'),
        row[2].find('img').get('alt'),
        row[3].find('img').get('alt'),
        row[4].find('img').get('alt'),
        int(row[5].text),
        int(row[6].text),
        int(row[7].text),
        int(row[8].text),
        int(row[9].text),
        int(row[10].text)
    ]

# %%
heroes_table
# Out:
#                            Hero                          Entry      Move  \
# 0             Abel: The Panther  Shadow Dragon / (New) Mystery   Cavalry
# 1       Aelfric: Custodian Monk                   Three Houses  Infantry
# 2        Alcryst: Tender Archer                         Engage  Infantry
# 3         Alcryst: Tender Groom                         Engage  Infantry
# 4        Alear: Awoken Divinity                         Engage  Infantry
# ...                         ...                            ...       ...
# 1247    Zephia: Scheming Dragon                         Engage    Flying
# 1248     Zephiel: The Liberator              The Binding Blade   Armored
# 1249    Zephiel: Winter's Crown              The Blazing Blade   Armored
# 1250  Zihark: Ninja Blademaster               Path of Radiance  Infantry
# 1251      Þjazi: Ruthless Jötun                         Heroes   Armored
#
#              Weapon  HP  Atk  Spd  Def  Res  Total
# 0        Blue Lance  39   33   32   25   25    154
# 1          Red Tome  43   40   31   20   37    171
# 2     Colorless Bow  39   43   46   30   24    182
# 3           Red Bow  40   44   46   35   23    188
# 4      Green Breath  40   41   47   33   37    198
# ...             ...  ..  ...  ...  ...  ...    ...
# 1247       Red Tome  41   40   44   23   24    172
# 1248      Red Sword  55   35   16   38   24    168
# 1249      Red Sword  48   38   19   38   36    179
# 1250      Red Sword  43   37   42   30   24    176
# 1251      Green Axe  49   50   18   47   42    206
#
# [1252 rows x 10 columns]

# %%
px.box(heroes_table, y=['HP', 'Atk', 'Spd', 'Def', 'Res'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\jerem\OneDrive\Documents\GitHub\tome-of-heroes\.venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\jerem\OneDrive\Documents\GitHub\tome-of-heroes\.venv\Lib\site-packages\plotly\basedatatypes.py:846, in BaseFigure._ipython_display_(self)
#     843 import plotly.io as pio
#     845 if pio.renderers.render_on_display and pio.renderers.default:
# --> 846     pio.show(self)
#     847 else:
#     848     print(repr(self))
#
# File c:\Users\jerem\OneDrive\Documents\GitHub\tome-of-heroes\.venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'alignmentgroup': 'True',
#               'hovertemplate': 'variable=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa'},
#               'name': '',
#               'notched': False,
#               'offsetgroup': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'box',
#               'x': array(['HP', 'HP', 'HP', ..., 'Res', 'Res', 'Res'], shape=(6260,), dtype=object),
#               'x0': ' ',
#               'xaxis': 'x',
#               'y': {'bdata': ('JysnKCgoKCgoKDMnKSkrKSsoLSooKS' ... 'kUIiktJCAeJR0aGSMeFSoZGBgkGCo='),
#                     'dtype': 'i1'},
#               'y0': ' ',
#               'yaxis': 'y'}],
#     'layout': {'boxmode': 'group',
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'variable'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'value'}}}
# })

# %%
px.bar(heroes_table, x='Weapon')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\jerem\OneDrive\Documents\GitHub\tome-of-heroes\.venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\jerem\OneDrive\Documents\GitHub\tome-of-heroes\.venv\Lib\site-packages\plotly\basedatatypes.py:846, in BaseFigure._ipython_display_(self)
#     843 import plotly.io as pio
#     845 if pio.renderers.render_on_display and pio.renderers.default:
# --> 846     pio.show(self)
#     847 else:
#     848     print(repr(self))
#
# File c:\Users\jerem\OneDrive\Documents\GitHub\tome-of-heroes\.venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'Weapon=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array(['Blue Lance', 'Red Tome', 'Colorless Bow', ..., 'Red Sword',
#                           'Red Sword', 'Green Axe'], shape=(1252,), dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQ=='),
#                     'dtype': 'i1'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Weapon'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'count'}}}
# })

# %%
def color(str):
    return str.split(' ')[0]

heroes_table['Color'] = heroes_table['Weapon'].apply(color)
heroes_table.head()
# Out:
#                       Hero                          Entry      Move  \
# 0        Abel: The Panther  Shadow Dragon / (New) Mystery   Cavalry
# 1  Aelfric: Custodian Monk                   Three Houses  Infantry
# 2   Alcryst: Tender Archer                         Engage  Infantry
# 3    Alcryst: Tender Groom                         Engage  Infantry
# 4   Alear: Awoken Divinity                         Engage  Infantry
#
#           Weapon  HP  Atk  Spd  Def  Res  Total      Color
# 0     Blue Lance  39   33   32   25   25    154       Blue
# 1       Red Tome  43   40   31   20   37    171        Red
# 2  Colorless Bow  39   43   46   30   24    182  Colorless
# 3        Red Bow  40   44   46   35   23    188        Red
# 4   Green Breath  40   41   47   33   37    198      Green

# %%
px.bar(heroes_table, x='Color')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\jerem\OneDrive\Documents\GitHub\tome-of-heroes\.venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\jerem\OneDrive\Documents\GitHub\tome-of-heroes\.venv\Lib\site-packages\plotly\basedatatypes.py:846, in BaseFigure._ipython_display_(self)
#     843 import plotly.io as pio
#     845 if pio.renderers.render_on_display and pio.renderers.default:
# --> 846     pio.show(self)
#     847 else:
#     848     print(repr(self))
#
# File c:\Users\jerem\OneDrive\Documents\GitHub\tome-of-heroes\.venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'Color=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array(['Blue', 'Red', 'Colorless', ..., 'Red', 'Red', 'Green'],
#                          shape=(1252,), dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQ=='),
#                     'dtype': 'i1'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Color'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'count'}}}
# })

# %%
heroes_table.to_csv('heroes_table.csv')
